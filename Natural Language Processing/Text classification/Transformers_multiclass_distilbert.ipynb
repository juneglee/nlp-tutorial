# %%
import json
import re
import pandas as pd
import numpy as np
import random

import torch
from torch import cuda
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from torch.utils.data import TensorDataset
import transformers
from transformers import DistilBertModel, DistilBertTokenizer, DistilBertConfig
from transformers import DistilBertForSequenceClassification
from transformers import AdamW, get_linear_schedule_with_warmup
from tqdm import tqdm
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
jd_data = pd.read_json("jd_7632.json")

# %%
jd_data.head()
# Out:
#    wd_id                  position  \
# 0  61852  고객 경험(CX) 전략 매니저 (신입/인턴)
# 1  61851               집무실 IoT 개발자
# 2  61850             공간(인테리어) 디자이너
# 3  61849       Python 웹 어플리케이션 개발자
# 4  61848             여행 숙박 콘텐츠 마케터
#
#                                           main_tasks  \
# 0  • 24시간 365일 운영되는 로켓펀치와 집무실 고객 경험 관리\n• 고객 경험 사...
# 1  • 집무실 인프라 구축: (IoT)전원 관리 설계 및 구성, QR 코드 기반 출입 ...
# 2  - 공간 아이덴티티 : 숙박시설, 공용공간, 객실 등 공간의 아이덴티티를 기획하고 ...
# 3                                    • 로켓펀치 웹 서비스 개발
# 4  • 투숙고객 대상 브랜딩-프로모션-예약-투숙-후기를 아우르는 일관된 마케팅 캠페인 ...
#
#                                         requirements  \
# 0  • 소셜 네트워크 또는 플랫폼 커뮤니티 등 온라인 플랫폼 운영에 관심이 있으신 분\...
# 1  •  IoT를 통한 공간 관리 및 자동화에 대한 높은 관심이 있어야 합니다.\n• ...
# 2  • 여행, 숙박업, 접객업, 프랜차이즈업에 대한 경험과 이해\n• CAD, Sket...
# 3  • 웹 개발 업무 2년 이상이 있어야 합니다.\n• Python 및 Django/F...
# 4  •  2~5년간 미디어, PR, 광고, 콘텐츠 기획/제작을 경험하신 분\n•  복잡...
#
#                                     preferred_points  category
# 0  • 회사와 함께 성장하고자 하는 의지를 가진 분\n• 다양한 이슈에 빠르게 대응하고...  경영, 비즈니스
# 1  • 적극적으로 서비스 개선에 필요한 업무를 찾고 개선할수 있는 인성과 역량\n•  ...        개발
# 2  •  숙박 운영 및 관리를 경험하신 분\n•  시니어 디자이너와 팀을 이뤄 프로젝트...       디자인
# 3  • 적극적으로 서비스 개선에 필요한 업무를 찾고 개선할수 있는 인성과 역량\n• S...        개발
# 4  • 숙박운영, 스타트업 업무문화 경험자\n•  유튜브, 브런치 등 뉴미디어를 다양하...   마케팅, 광고

# %%
jd_data["category"].unique()
# Out:
# array(['경영, 비즈니스', '개발', '디자인', '마케팅, 광고'], dtype=object)

# %%
# 결측치 확인
jd_data.isnull().sum()
# Out:
# wd_id                 0
# position              6
# main_tasks            0
# requirements          6
# preferred_points    265
# category              0
# dtype: int64

# %%
# category 비율 확인
jd_data.category.value_counts()
# Out:
# 개발          3419
# 경영, 비즈니스    1799
# 마케팅, 광고     1361
# 디자인         1053
# Name: category, dtype: int64

# %%
possible_labels = jd_data.category.unique()

label_dict = {}
for index, possible_label in enumerate(possible_labels):
    label_dict[possible_label] = index
label_dict
# Out:
# {'경영, 비즈니스': 0, '개발': 1, '디자인': 2, '마케팅, 광고': 3}

# %%
jd_data['category'] = jd_data.category.replace(label_dict)

# %%
# 문장을 함쳐 하나의 문장으로 정리 
jd_data["total"] = jd_data.position + " " + jd_data.main_tasks + " " +jd_data.requirements + " " +jd_data.preferred_points 
jd_data['total']
# Out:
# 0       고객 경험(CX) 전략 매니저 (신입/인턴) • 24시간 365일 운영되는 로켓펀치...
# 1       집무실 IoT 개발자 • 집무실 인프라 구축: (IoT)전원 관리 설계 및 구성, ...
# 2       공간(인테리어) 디자이너 - 공간 아이덴티티 : 숙박시설, 공용공간, 객실 등 공간...
# 3       Python 웹 어플리케이션 개발자 • 로켓펀치 웹 서비스 개발 • 웹 개발 업무 ...
# 4       여행 숙박 콘텐츠 마케터 • 투숙고객 대상 브랜딩-프로모션-예약-투숙-후기를 아우르...
#                               ...
# 7627    Senior Product Designer (UX) 1. Product UX Des...
# 7628    WIPPY, QUAT 데이터 분석가 (시니어) • 서비스 고도화를 위한 현황 분석 ...
# 7629    UI Designer • 신규 모바일 앱 디자인 및 고도화 • 유저 경험에 기반한 ...
# 7630    Data Engineer 담당 개발자 1. 운영중인 AWS기반의 ETL/ELT 개발...
# 7631                                                  NaN
# Name: total, Length: 7632, dtype: object

# %%
# 무의미한 정보를 정규화 작업을 통해서 제거 
def clean_text(text):
#     text_clean = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", " ", str(text))
    text_clean = re.sub(r'\d+','',str(text))
    text_clean = re.sub(r"^\s+", '', text_clean) #remove space from start 
    text_clean = re.sub(r'\s+$', '', text_clean) #remove space from the end corpus.append(review) return corpus
    text_clean = re.sub(r'<[^>]+>','',text_clean) #remove Html tags
    text_clean = re.sub(r'^\s*\d+\s*[-\\.)]?\s+|^\s*[-•■⦿*:º○▶️⏩✔•]\s+', '', text_clean).strip()# 불필요한 유니코드 및 특수문자 제거
    text_clean = re.sub(r"[\<\(\[\]\)\>]", " ", text_clean) # 불필요한 괄호 제거
    text_clean = re.sub(r"(http|https)?:\/\/\S+\b|www\.(\w+\.)+\S*", "", text_clean).strip()
    text_clean = re.sub(r"pic\.(\w+\.)+\S*", "", text_clean).strip() # URL형태의 주소 제거
    text_clean = re.sub(r"\s+", " ", text_clean).strip() # 두개이상의 연속된 공백을 제거
    text_clean = text_clean.replace("•", " ") # 슬래쉬 기호 제거
    text_clean = text_clean.replace("/", " ") # 슬래쉬 기호 제거
    return text_clean

# %%
# text_clean process
jd_data["total_clean"] = jd_data["total"].map(lambda text : clean_text(text))

# %%
df_train = jd_data[['total_clean', 'category']]
df_train.head()
# Out:
#                                          total_clean  category
# 0  고객 경험 CX 전략 매니저 신입 인턴   시간 일 운영되는 로켓펀치와 집무실 고객...         0
# 1  집무실 IoT 개발자   집무실 인프라 구축: IoT 전원 관리 설계 및 구성, Q...         1
# 2  공간 인테리어 디자이너 - 공간 아이덴티티 : 숙박시설, 공용공간, 객실 등 공간의...         2
# 3  Python 웹 어플리케이션 개발자   로켓펀치 웹 서비스 개발   웹 개발 업무 ...         1
# 4  여행 숙박 콘텐츠 마케터   투숙고객 대상 브랜딩-프로모션-예약-투숙-후기를 아우르...         3

# %%
X_train, X_val, y_train, y_val = train_test_split(df_train.index.values, 
                                                  df_train.category.values, 
                                                  test_size=0.15, 
                                                  random_state=42, 
                                                  stratify=df_train.category.values)

df_train['data_type'] = ['not_set']*df_train.shape[0]

df_train.loc[X_train, 'data_type'] = 'train'
df_train.loc[X_val, 'data_type'] = 'val'

df_train.groupby(['category', 'data_type']).count()
# Out:
# C:\Users\User\anaconda3\envs\test\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\User\anaconda3\envs\test\lib\site-packages\pandas\core\indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                     total_clean
# category data_type
# 0        train             1529
#          val                270
# 1        train             2906
#          val                513
# 2        train              895
#          val                158
# 3        train             1157
#          val                204

# %%
MAX_LENGTH = 256
TRAIN_BATCH_SIZE = 8
VALID_BATCH_SIZE = 4
EPOCHS = 1
LEARNING_RATE = 1e-05

# %%
MODEL_NAME = 'distilbert-base-multilingual-cased'

# %%
tokenizer = DistilBertTokenizer.from_pretrained(MODEL_NAME, do_lower_case=True )

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df_train[df_train.data_type=='train'].total_clean.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)

encoded_data_val = tokenizer.batch_encode_plus(
    df_train[df_train.data_type=='val'].total_clean.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df_train[df_train.data_type=='train'].category.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(df_train[df_train.data_type=='val'].category.values)

dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)
# Out:
# Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-multilingual-cased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# Some weights of the model checkpoint at distilbert-base-multilingual-cased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-multilingual-cased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
batch_size = 3

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val, 
                                   sampler=SequentialSampler(dataset_val), 
                                   batch_size=batch_size)

# %%
optimizer = AdamW(model.parameters(),
                  lr=1e-5, 
                  eps=1e-8)
                  
epochs = 5

scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in label_dict.items()}
    print(f'label_dict_inverse: {label_dict_inverse}')
    
#     preds_test = np.argmax(preds, axis=0)w
#     print(f'preds: {preds_test}')www
    preds_flat = np.argmax(preds, axis=1).flatten()
#     print(f'preds_flat: {preds_flat}')
    labels_flat = labels.flatten()
#     print(f'labels_flat: {labels_flat}')

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
#         print(f'Class: {y_preds}')
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
device = "cuda:0"
model = model.to(device)

# %%
seed_val = 17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'finetuned_BERT_epoch_{epoch}.pt')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Epoch 1:   0%|                                                                                | 0/2163 [00:00<?, ?it/s]
# Epoch 1:   0%|                                                           | 0/2163 [00:00<?, ?it/s, training_loss=0.436]
# Epoch 1:   0%|                                                   | 1/2163 [00:00<28:35,  1.26it/s, training_loss=0.436]
# Epoch 1:   0%|                                                   | 1/2163 [00:00<28:35,  1.26it/s, training_loss=0.448]
# Epoch 1:   0%|                                                   | 2/2163 [00:00<16:04,  2.24it/s, training_loss=0.448]
# Epoch 1:   0%|                                                   | 2/2163 [00:01<16:04,  2.24it/s, training_loss=0.432]
# Epoch 1:   0%|                                                   | 3/2163 [00:01<11:58,  3.00it/s, training_loss=0.432]
# Epoch 1:   0%|                                                   | 3/2163 [00:01<11:58,  3.00it/s, training_loss=0.431]
# Epoch 1:   0%|                                                   | 4/2163 [00:01<10:04,  3.57it/s, training_loss=0.431]
# Epoch 1:   0%|                                                   | 4/2163 [00:01<10:04,  3.57it/s, training_loss=0.394]
# Epoch 1:   0%|                                                   | 5/2163 [00:01<08:58,  4.00it/s, training_loss=0.394]
# Epoch 1:   0%|                                                   | 5/2163 [00:01<08:58,  4.00it/s, training_loss=0.416]
# Epoch 1:   0%|▏                                                  | 6/2163 [00:01<08:20,  4.31it/s, training_loss=0.416]
# Epoch 1:   0%|▏                                                  | 6/2163 [00:01<08:20,  4.31it/s, training_loss=0.432]
# Epoch 1:   0%|▏                                                  | 7/2163 [00:01<07:56,  4.53it/s, training_loss=0.432]
# Epoch 1:   0%|▏                                                  | 7/2163 [00:02<07:56,  4.53it/s, training_loss=0.470]
# Epoch 1:   0%|▏                                                  | 8/2163 [00:02<07:39,  4.69it/s, training_loss=0.470]
# Epoch 1:   0%|▏                                                  | 8/2163 [00:02<07:39,  4.69it/s, training_loss=0.479]
# Epoch 1:   0%|▏                                                  | 9/2163 [00:02<07:29,  4.79it/s, training_loss=0.479]
# Epoch 1:   0%|▏                                                  | 9/2163 [00:02<07:29,  4.79it/s, training_loss=0.463]
# Epoch 1:   0%|▏                                                 | 10/2163 [00:02<07:22,  4.87it/s, training_loss=0.463]
# Epoch 1:   0%|▏                                                 | 10/2163 [00:02<07:22,  4.87it/s, training_loss=0.409]
# Epoch 1:   1%|▎                                                 | 11/2163 [00:02<07:16,  4.93it/s, training_loss=0.409]
# Epoch 1:   1%|▎                                                 | 11/2163 [00:02<07:16,  4.93it/s, training_loss=0.356]
# Epoch 1:   1%|▎                                                 | 12/2163 [00:02<07:13,  4.96it/s, training_loss=0.356]
# Epoch 1:   1%|▎                                                 | 12/2163 [00:03<07:13,  4.96it/s, training_loss=0.494]
# Epoch 1:   1%|▎                                                 | 13/2163 [00:03<07:10,  4.99it/s, training_loss=0.494]
# Epoch 1:   1%|▎                                                 | 13/2163 [00:03<07:10,  4.99it/s, training_loss=0.414]
# Epoch 1:   1%|▎                                                 | 14/2163 [00:03<07:07,  5.02it/s, training_loss=0.414]
# Epoch 1:   1%|▎                                                 | 14/2163 [00:03<07:07,  5.02it/s, training_loss=0.411]
# Epoch 1:   1%|▎                                                 | 15/2163 [00:03<07:07,  5.03it/s, training_loss=0.411]
# Epoch 1:   1%|▎                                                 | 15/2163 [00:03<07:07,  5.03it/s, training_loss=0.435]
# Epoch 1:   1%|▎                                                 | 16/2163 [00:03<07:06,  5.03it/s, training_loss=0.435]
# Epoch 1:   1%|▎                                                 | 16/2163 [00:03<07:06,  5.03it/s, training_loss=0.417]
# Epoch 1:   1%|▍                                                 | 17/2163 [00:03<07:05,  5.05it/s, training_loss=0.417]
# Epoch 1:   1%|▍                                                 | 17/2163 [00:04<07:05,  5.05it/s, training_loss=0.559]
# Epoch 1:   1%|▍                                                 | 18/2163 [00:04<07:04,  5.05it/s, training_loss=0.559]
# Epoch 1:   1%|▍                                                 | 18/2163 [00:04<07:04,  5.05it/s, training_loss=0.387]
# Epoch 1:   1%|▍                                                 | 19/2163 [00:04<07:05,  5.04it/s, training_loss=0.387]
# Epoch 1:   1%|▍                                                 | 19/2163 [00:04<07:05,  5.04it/s, training_loss=0.461]
# Epoch 1:   1%|▍                                                 | 20/2163 [00:04<07:04,  5.05it/s, training_loss=0.461]
# Epoch 1:   1%|▍                                                 | 20/2163 [00:04<07:04,  5.05it/s, training_loss=0.478]
# Epoch 1:   1%|▍                                                 | 21/2163 [00:04<07:04,  5.05it/s, training_loss=0.478]
# Epoch 1:   1%|▍                                                 | 21/2163 [00:04<07:04,  5.05it/s, training_loss=0.372]
# Epoch 1:   1%|▌                                                 | 22/2163 [00:04<07:03,  5.06it/s, training_loss=0.372]
# Epoch 1:   1%|▌                                                 | 22/2163 [00:05<07:03,  5.06it/s, training_loss=0.538]
# Epoch 1:   1%|▌                                                 | 23/2163 [00:05<07:02,  5.06it/s, training_loss=0.538]
# Epoch 1:   1%|▌                                                 | 23/2163 [00:05<07:02,  5.06it/s, training_loss=0.480]
# Epoch 1:   1%|▌                                                 | 24/2163 [00:05<07:01,  5.07it/s, training_loss=0.480]
# Epoch 1:   1%|▌                                                 | 24/2163 [00:05<07:01,  5.07it/s, training_loss=0.453]
# Epoch 1:   1%|▌                                                 | 25/2163 [00:05<07:02,  5.06it/s, training_loss=0.453]
# Epoch 1:   1%|▌                                                 | 25/2163 [00:05<07:02,  5.06it/s, training_loss=0.450]
# Epoch 1:   1%|▌                                                 | 26/2163 [00:05<07:01,  5.07it/s, training_loss=0.450]
# Epoch 1:   1%|▌                                                 | 26/2163 [00:05<07:01,  5.07it/s, training_loss=0.514]
# Epoch 1:   1%|▌                                                 | 27/2163 [00:05<07:01,  5.07it/s, training_loss=0.514]
# Epoch 1:   1%|▌                                                 | 27/2163 [00:06<07:01,  5.07it/s, training_loss=0.402]
# Epoch 1:   1%|▋                                                 | 28/2163 [00:06<07:00,  5.08it/s, training_loss=0.402]
# Epoch 1:   1%|▋                                                 | 28/2163 [00:06<07:00,  5.08it/s, training_loss=0.383]
# Epoch 1:   1%|▋                                                 | 29/2163 [00:06<07:00,  5.07it/s, training_loss=0.383]
# Epoch 1:   1%|▋                                                 | 29/2163 [00:06<07:00,  5.07it/s, training_loss=0.458]
# Epoch 1:   1%|▋                                                 | 30/2163 [00:06<07:00,  5.07it/s, training_loss=0.458]
# Epoch 1:   1%|▋                                                 | 30/2163 [00:06<07:00,  5.07it/s, training_loss=0.378]
# Epoch 1:   1%|▋                                                 | 31/2163 [00:06<06:59,  5.08it/s, training_loss=0.378]
# Epoch 1:   1%|▋                                                 | 31/2163 [00:06<06:59,  5.08it/s, training_loss=0.391]
# Epoch 1:   1%|▋                                                 | 32/2163 [00:06<06:59,  5.08it/s, training_loss=0.391]
# Epoch 1:   1%|▋                                                 | 32/2163 [00:07<06:59,  5.08it/s, training_loss=0.498]
# Epoch 1:   2%|▊                                                 | 33/2163 [00:07<07:00,  5.07it/s, training_loss=0.498]
# Epoch 1:   2%|▊                                                 | 33/2163 [00:07<07:00,  5.07it/s, training_loss=0.480]
# Epoch 1:   2%|▊                                                 | 34/2163 [00:07<07:00,  5.06it/s, training_loss=0.480]
# Epoch 1:   2%|▊                                                 | 34/2163 [00:07<07:00,  5.06it/s, training_loss=0.490]
# Epoch 1:   2%|▊                                                 | 35/2163 [00:07<06:59,  5.07it/s, training_loss=0.490]
# Epoch 1:   2%|▊                                                 | 35/2163 [00:07<06:59,  5.07it/s, training_loss=0.379]
# Epoch 1:   2%|▊                                                 | 36/2163 [00:07<06:59,  5.07it/s, training_loss=0.379]
# Epoch 1:   2%|▊                                                 | 36/2163 [00:07<06:59,  5.07it/s, training_loss=0.416]
# Epoch 1:   2%|▊                                                 | 37/2163 [00:07<07:00,  5.06it/s, training_loss=0.416]
# Epoch 1:   2%|▊                                                 | 37/2163 [00:08<07:00,  5.06it/s, training_loss=0.531]
# Epoch 1:   2%|▉                                                 | 38/2163 [00:08<06:58,  5.07it/s, training_loss=0.531]
# Epoch 1:   2%|▉                                                 | 38/2163 [00:08<06:58,  5.07it/s, training_loss=0.393]
# Epoch 1:   2%|▉                                                 | 39/2163 [00:08<06:59,  5.06it/s, training_loss=0.393]
# Epoch 1:   2%|▉                                                 | 39/2163 [00:08<06:59,  5.06it/s, training_loss=0.440]
# Epoch 1:   2%|▉                                                 | 40/2163 [00:08<06:59,  5.07it/s, training_loss=0.440]
# Epoch 1:   2%|▉                                                 | 40/2163 [00:08<06:59,  5.07it/s, training_loss=0.517]
# Epoch 1:   2%|▉                                                 | 41/2163 [00:08<06:58,  5.07it/s, training_loss=0.517]
# Epoch 1:   2%|▉                                                 | 41/2163 [00:08<06:58,  5.07it/s, training_loss=0.557]
# Epoch 1:   2%|▉                                                 | 42/2163 [00:08<06:57,  5.08it/s, training_loss=0.557]
# Epoch 1:   2%|▉                                                 | 42/2163 [00:09<06:57,  5.08it/s, training_loss=0.531]
# Epoch 1:   2%|▉                                                 | 43/2163 [00:09<06:59,  5.05it/s, training_loss=0.531]
# Epoch 1:   2%|▉                                                 | 43/2163 [00:09<06:59,  5.05it/s, training_loss=0.451]
# Epoch 1:   2%|█                                                 | 44/2163 [00:09<06:58,  5.06it/s, training_loss=0.451]
# Epoch 1:   2%|█                                                 | 44/2163 [00:09<06:58,  5.06it/s, training_loss=0.441]
# Epoch 1:   2%|█                                                 | 45/2163 [00:09<06:59,  5.05it/s, training_loss=0.441]
# Epoch 1:   2%|█                                                 | 45/2163 [00:09<06:59,  5.05it/s, training_loss=0.361]
# Epoch 1:   2%|█                                                 | 46/2163 [00:09<06:58,  5.06it/s, training_loss=0.361]
# Epoch 1:   2%|█                                                 | 46/2163 [00:09<06:58,  5.06it/s, training_loss=0.327]
# Epoch 1:   2%|█                                                 | 47/2163 [00:09<06:58,  5.06it/s, training_loss=0.327]
# Epoch 1:   2%|█                                                 | 47/2163 [00:10<06:58,  5.06it/s, training_loss=0.416]
# Epoch 1:   2%|█                                                 | 48/2163 [00:10<06:59,  5.04it/s, training_loss=0.416]
# Epoch 1:   2%|█                                                 | 48/2163 [00:10<06:59,  5.04it/s, training_loss=0.411]
# Epoch 1:   2%|█▏                                                | 49/2163 [00:10<07:00,  5.03it/s, training_loss=0.411]
# Epoch 1:   2%|█▏                                                | 49/2163 [00:10<07:00,  5.03it/s, training_loss=0.392]
# Epoch 1:   2%|█▏                                                | 50/2163 [00:10<06:59,  5.04it/s, training_loss=0.392]
# Epoch 1:   2%|█▏                                                | 50/2163 [00:10<06:59,  5.04it/s, training_loss=0.357]
# Epoch 1:   2%|█▏                                                | 51/2163 [00:10<06:59,  5.04it/s, training_loss=0.357]
# Epoch 1:   2%|█▏                                                | 51/2163 [00:10<06:59,  5.04it/s, training_loss=0.440]
# Epoch 1:   2%|█▏                                                | 52/2163 [00:10<06:58,  5.04it/s, training_loss=0.440]
# Epoch 1:   2%|█▏                                                | 52/2163 [00:11<06:58,  5.04it/s, training_loss=0.350]
# Epoch 1:   2%|█▏                                                | 53/2163 [00:11<06:57,  5.05it/s, training_loss=0.350]
# Epoch 1:   2%|█▏                                                | 53/2163 [00:11<06:57,  5.05it/s, training_loss=0.363]
# Epoch 1:   2%|█▏                                                | 54/2163 [00:11<06:57,  5.05it/s, training_loss=0.363]
# Epoch 1:   2%|█▏                                                | 54/2163 [00:11<06:57,  5.05it/s, training_loss=0.271]
# Epoch 1:   3%|█▎                                                | 55/2163 [00:11<06:57,  5.05it/s, training_loss=0.271]
# Epoch 1:   3%|█▎                                                | 55/2163 [00:11<06:57,  5.05it/s, training_loss=0.426]
# Epoch 1:   3%|█▎                                                | 56/2163 [00:11<06:56,  5.06it/s, training_loss=0.426]
# Epoch 1:   3%|█▎                                                | 56/2163 [00:11<06:56,  5.06it/s, training_loss=0.470]
# Epoch 1:   3%|█▎                                                | 57/2163 [00:11<06:55,  5.06it/s, training_loss=0.470]
# Epoch 1:   3%|█▎                                                | 57/2163 [00:12<06:55,  5.06it/s, training_loss=0.455]
# Epoch 1:   3%|█▎                                                | 58/2163 [00:12<06:56,  5.05it/s, training_loss=0.455]
# Epoch 1:   3%|█▎                                                | 58/2163 [00:12<06:56,  5.05it/s, training_loss=0.389]
# Epoch 1:   3%|█▎                                                | 59/2163 [00:12<06:56,  5.05it/s, training_loss=0.389]
# Epoch 1:   3%|█▎                                                | 59/2163 [00:12<06:56,  5.05it/s, training_loss=0.342]
# Epoch 1:   3%|█▍                                                | 60/2163 [00:12<06:56,  5.05it/s, training_loss=0.342]
# Epoch 1:   3%|█▍                                                | 60/2163 [00:12<06:56,  5.05it/s, training_loss=0.360]
# Epoch 1:   3%|█▍                                                | 61/2163 [00:12<06:54,  5.07it/s, training_loss=0.360]
# Epoch 1:   3%|█▍                                                | 61/2163 [00:12<06:54,  5.07it/s, training_loss=0.236]
# Epoch 1:   3%|█▍                                                | 62/2163 [00:12<06:54,  5.07it/s, training_loss=0.236]
# Epoch 1:   3%|█▍                                                | 62/2163 [00:13<06:54,  5.07it/s, training_loss=0.303]
# Epoch 1:   3%|█▍                                                | 63/2163 [00:13<06:54,  5.06it/s, training_loss=0.303]
# Epoch 1:   3%|█▍                                                | 63/2163 [00:13<06:54,  5.06it/s, training_loss=0.321]
# Epoch 1:   3%|█▍                                                | 64/2163 [00:13<06:54,  5.07it/s, training_loss=0.321]
# Epoch 1:   3%|█▍                                                | 64/2163 [00:13<06:54,  5.07it/s, training_loss=0.301]
# Epoch 1:   3%|█▌                                                | 65/2163 [00:13<06:54,  5.06it/s, training_loss=0.301]
# Epoch 1:   3%|█▌                                                | 65/2163 [00:13<06:54,  5.06it/s, training_loss=0.304]
# Epoch 1:   3%|█▌                                                | 66/2163 [00:13<06:54,  5.06it/s, training_loss=0.304]
# Epoch 1:   3%|█▌                                                | 66/2163 [00:13<06:54,  5.06it/s, training_loss=0.537]
# Epoch 1:   3%|█▌                                                | 67/2163 [00:13<06:54,  5.06it/s, training_loss=0.537]
# Epoch 1:   3%|█▌                                                | 67/2163 [00:14<06:54,  5.06it/s, training_loss=0.295]
# Epoch 1:   3%|█▌                                                | 68/2163 [00:14<06:54,  5.05it/s, training_loss=0.295]
# Epoch 1:   3%|█▌                                                | 68/2163 [00:14<06:54,  5.05it/s, training_loss=0.136]
# Epoch 1:   3%|█▌                                                | 69/2163 [00:14<06:53,  5.07it/s, training_loss=0.136]
# Epoch 1:   3%|█▌                                                | 69/2163 [00:14<06:53,  5.07it/s, training_loss=0.315]
# Epoch 1:   3%|█▌                                                | 70/2163 [00:14<06:54,  5.05it/s, training_loss=0.315]
# Epoch 1:   3%|█▌                                                | 70/2163 [00:14<06:54,  5.05it/s, training_loss=0.133]
# Epoch 1:   3%|█▋                                                | 71/2163 [00:14<06:52,  5.07it/s, training_loss=0.133]
# Epoch 1:   3%|█▋                                                | 71/2163 [00:14<06:52,  5.07it/s, training_loss=0.287]
# Epoch 1:   3%|█▋                                                | 72/2163 [00:14<06:52,  5.07it/s, training_loss=0.287]
# Epoch 1:   3%|█▋                                                | 72/2163 [00:15<06:52,  5.07it/s, training_loss=0.616]
# Epoch 1:   3%|█▋                                                | 73/2163 [00:15<06:52,  5.06it/s, training_loss=0.616]
# Epoch 1:   3%|█▋                                                | 73/2163 [00:15<06:52,  5.06it/s, training_loss=0.354]
# Epoch 1:   3%|█▋                                                | 74/2163 [00:15<06:52,  5.06it/s, training_loss=0.354]
# Epoch 1:   3%|█▋                                                | 74/2163 [00:15<06:52,  5.06it/s, training_loss=0.325]
# Epoch 1:   3%|█▋                                                | 75/2163 [00:15<06:51,  5.07it/s, training_loss=0.325]
# Epoch 1:   3%|█▋                                                | 75/2163 [00:15<06:51,  5.07it/s, training_loss=0.328]
# Epoch 1:   4%|█▊                                                | 76/2163 [00:15<06:52,  5.06it/s, training_loss=0.328]
# Epoch 1:   4%|█▊                                                | 76/2163 [00:15<06:52,  5.06it/s, training_loss=0.310]
# Epoch 1:   4%|█▊                                                | 77/2163 [00:15<06:51,  5.07it/s, training_loss=0.310]
# Epoch 1:   4%|█▊                                                | 77/2163 [00:16<06:51,  5.07it/s, training_loss=0.138]
# Epoch 1:   4%|█▊                                                | 78/2163 [00:16<06:51,  5.06it/s, training_loss=0.138]
# Epoch 1:   4%|█▊                                                | 78/2163 [00:16<06:51,  5.06it/s, training_loss=0.116]
# Epoch 1:   4%|█▊                                                | 79/2163 [00:16<06:53,  5.04it/s, training_loss=0.116]
# Epoch 1:   4%|█▊                                                | 79/2163 [00:16<06:53,  5.04it/s, training_loss=0.625]
# Epoch 1:   4%|█▊                                                | 80/2163 [00:16<06:51,  5.06it/s, training_loss=0.625]
# Epoch 1:   4%|█▊                                                | 80/2163 [00:16<06:51,  5.06it/s, training_loss=0.485]
# Epoch 1:   4%|█▊                                                | 81/2163 [00:16<06:51,  5.05it/s, training_loss=0.485]
# Epoch 1:   4%|█▊                                                | 81/2163 [00:16<06:51,  5.05it/s, training_loss=0.362]
# Epoch 1:   4%|█▉                                                | 82/2163 [00:16<06:51,  5.05it/s, training_loss=0.362]
# Epoch 1:   4%|█▉                                                | 82/2163 [00:17<06:51,  5.05it/s, training_loss=0.675]
# Epoch 1:   4%|█▉                                                | 83/2163 [00:17<06:51,  5.06it/s, training_loss=0.675]
# Epoch 1:   4%|█▉                                                | 83/2163 [00:17<06:51,  5.06it/s, training_loss=0.117]
# Epoch 1:   4%|█▉                                                | 84/2163 [00:17<06:51,  5.05it/s, training_loss=0.117]
# Epoch 1:   4%|█▉                                                | 84/2163 [00:17<06:51,  5.05it/s, training_loss=0.452]
# Epoch 1:   4%|█▉                                                | 85/2163 [00:17<06:50,  5.06it/s, training_loss=0.452]
# Epoch 1:   4%|█▉                                                | 85/2163 [00:17<06:50,  5.06it/s, training_loss=0.277]
# Epoch 1:   4%|█▉                                                | 86/2163 [00:17<06:50,  5.05it/s, training_loss=0.277]
# Epoch 1:   4%|█▉                                                | 86/2163 [00:17<06:50,  5.05it/s, training_loss=0.542]
# Epoch 1:   4%|██                                                | 87/2163 [00:17<06:49,  5.07it/s, training_loss=0.542]
# Epoch 1:   4%|██                                                | 87/2163 [00:17<06:49,  5.07it/s, training_loss=0.386]
# Epoch 1:   4%|██                                                | 88/2163 [00:17<06:50,  5.06it/s, training_loss=0.386]
# Epoch 1:   4%|██                                                | 88/2163 [00:18<06:50,  5.06it/s, training_loss=0.282]
# Epoch 1:   4%|██                                                | 89/2163 [00:18<06:50,  5.05it/s, training_loss=0.282]
# Epoch 1:   4%|██                                                | 89/2163 [00:18<06:50,  5.05it/s, training_loss=0.518]
# Epoch 1:   4%|██                                                | 90/2163 [00:18<06:49,  5.06it/s, training_loss=0.518]
# Epoch 1:   4%|██                                                | 90/2163 [00:18<06:49,  5.06it/s, training_loss=0.276]
# Epoch 1:   4%|██                                                | 91/2163 [00:18<06:50,  5.04it/s, training_loss=0.276]
# Epoch 1:   4%|██                                                | 91/2163 [00:18<06:50,  5.04it/s, training_loss=0.238]
# Epoch 1:   4%|██▏                                               | 92/2163 [00:18<06:50,  5.05it/s, training_loss=0.238]
# Epoch 1:   4%|██▏                                               | 92/2163 [00:18<06:50,  5.05it/s, training_loss=0.377]
# Epoch 1:   4%|██▏                                               | 93/2163 [00:18<06:49,  5.06it/s, training_loss=0.377]
# Epoch 1:   4%|██▏                                               | 93/2163 [00:19<06:49,  5.06it/s, training_loss=0.508]
# Epoch 1:   4%|██▏                                               | 94/2163 [00:19<06:49,  5.05it/s, training_loss=0.508]
# Epoch 1:   4%|██▏                                               | 94/2163 [00:19<06:49,  5.05it/s, training_loss=0.370]
# Epoch 1:   4%|██▏                                               | 95/2163 [00:19<06:48,  5.06it/s, training_loss=0.370]
# Epoch 1:   4%|██▏                                               | 95/2163 [00:19<06:48,  5.06it/s, training_loss=0.258]
# Epoch 1:   4%|██▏                                               | 96/2163 [00:19<06:49,  5.05it/s, training_loss=0.258]
# Epoch 1:   4%|██▏                                               | 96/2163 [00:19<06:49,  5.05it/s, training_loss=0.153]
# Epoch 1:   4%|██▏                                               | 97/2163 [00:19<06:49,  5.05it/s, training_loss=0.153]
# Epoch 1:   4%|██▏                                               | 97/2163 [00:19<06:49,  5.05it/s, training_loss=0.356]
# Epoch 1:   5%|██▎                                               | 98/2163 [00:19<06:48,  5.05it/s, training_loss=0.356]
# Epoch 1:   5%|██▎                                               | 98/2163 [00:20<06:48,  5.05it/s, training_loss=0.215]
# Epoch 1:   5%|██▎                                               | 99/2163 [00:20<06:47,  5.06it/s, training_loss=0.215]
# Epoch 1:   5%|██▎                                               | 99/2163 [00:20<06:47,  5.06it/s, training_loss=0.622]
# Epoch 1:   5%|██▎                                              | 100/2163 [00:20<06:47,  5.06it/s, training_loss=0.622]
# Epoch 1:   5%|██▎                                              | 100/2163 [00:20<06:47,  5.06it/s, training_loss=0.179]
# Epoch 1:   5%|██▎                                              | 101/2163 [00:20<06:47,  5.06it/s, training_loss=0.179]
# Epoch 1:   5%|██▎                                              | 101/2163 [00:20<06:47,  5.06it/s, training_loss=0.370]
# Epoch 1:   5%|██▎                                              | 102/2163 [00:20<06:48,  5.05it/s, training_loss=0.370]
# Epoch 1:   5%|██▎                                              | 102/2163 [00:20<06:48,  5.05it/s, training_loss=0.096]
# Epoch 1:   5%|██▎                                              | 103/2163 [00:20<06:47,  5.06it/s, training_loss=0.096]
# Epoch 1:   5%|██▎                                              | 103/2163 [00:21<06:47,  5.06it/s, training_loss=0.579]
# Epoch 1:   5%|██▎                                              | 104/2163 [00:21<06:48,  5.05it/s, training_loss=0.579]
# Epoch 1:   5%|██▎                                              | 104/2163 [00:21<06:48,  5.05it/s, training_loss=0.433]
# Epoch 1:   5%|██▍                                              | 105/2163 [00:21<06:47,  5.05it/s, training_loss=0.433]
# Epoch 1:   5%|██▍                                              | 105/2163 [00:21<06:47,  5.05it/s, training_loss=0.286]
# Epoch 1:   5%|██▍                                              | 106/2163 [00:21<06:47,  5.05it/s, training_loss=0.286]
# Epoch 1:   5%|██▍                                              | 106/2163 [00:21<06:47,  5.05it/s, training_loss=0.169]
# Epoch 1:   5%|██▍                                              | 107/2163 [00:21<06:46,  5.06it/s, training_loss=0.169]
# Epoch 1:   5%|██▍                                              | 107/2163 [00:21<06:46,  5.06it/s, training_loss=0.189]
# Epoch 1:   5%|██▍                                              | 108/2163 [00:21<06:48,  5.03it/s, training_loss=0.189]
# Epoch 1:   5%|██▍                                              | 108/2163 [00:22<06:48,  5.03it/s, training_loss=0.581]
# Epoch 1:   5%|██▍                                              | 109/2163 [00:22<06:47,  5.04it/s, training_loss=0.581]
# Epoch 1:   5%|██▍                                              | 109/2163 [00:22<06:47,  5.04it/s, training_loss=0.280]
# Epoch 1:   5%|██▍                                              | 110/2163 [00:22<06:48,  5.03it/s, training_loss=0.280]
# Epoch 1:   5%|██▍                                              | 110/2163 [00:22<06:48,  5.03it/s, training_loss=0.301]
# Epoch 1:   5%|██▌                                              | 111/2163 [00:22<06:48,  5.03it/s, training_loss=0.301]
# Epoch 1:   5%|██▌                                              | 111/2163 [00:22<06:48,  5.03it/s, training_loss=0.340]
# Epoch 1:   5%|██▌                                              | 112/2163 [00:22<06:48,  5.02it/s, training_loss=0.340]
# Epoch 1:   5%|██▌                                              | 112/2163 [00:22<06:48,  5.02it/s, training_loss=0.492]
# Epoch 1:   5%|██▌                                              | 113/2163 [00:22<06:47,  5.02it/s, training_loss=0.492]
# Epoch 1:   5%|██▌                                              | 113/2163 [00:23<06:47,  5.02it/s, training_loss=0.319]
# Epoch 1:   5%|██▌                                              | 114/2163 [00:23<06:47,  5.03it/s, training_loss=0.319]
# Epoch 1:   5%|██▌                                              | 114/2163 [00:23<06:47,  5.03it/s, training_loss=0.458]
# Epoch 1:   5%|██▌                                              | 115/2163 [00:23<06:47,  5.03it/s, training_loss=0.458]
# Epoch 1:   5%|██▌                                              | 115/2163 [00:23<06:47,  5.03it/s, training_loss=0.660]
# Epoch 1:   5%|██▋                                              | 116/2163 [00:23<06:47,  5.02it/s, training_loss=0.660]
# Epoch 1:   5%|██▋                                              | 116/2163 [00:23<06:47,  5.02it/s, training_loss=0.157]
# Epoch 1:   5%|██▋                                              | 117/2163 [00:23<06:47,  5.02it/s, training_loss=0.157]
# Epoch 1:   5%|██▋                                              | 117/2163 [00:23<06:47,  5.02it/s, training_loss=0.317]
# Epoch 1:   5%|██▋                                              | 118/2163 [00:23<06:47,  5.02it/s, training_loss=0.317]
# Epoch 1:   5%|██▋                                              | 118/2163 [00:24<06:47,  5.02it/s, training_loss=0.440]
# Epoch 1:   6%|██▋                                              | 119/2163 [00:24<06:46,  5.03it/s, training_loss=0.440]
# Epoch 1:   6%|██▋                                              | 119/2163 [00:24<06:46,  5.03it/s, training_loss=0.492]
# Epoch 1:   6%|██▋                                              | 120/2163 [00:24<06:45,  5.04it/s, training_loss=0.492]
# Epoch 1:   6%|██▋                                              | 120/2163 [00:24<06:45,  5.04it/s, training_loss=0.302]
# Epoch 1:   6%|██▋                                              | 121/2163 [00:24<06:47,  5.02it/s, training_loss=0.302]
# Epoch 1:   6%|██▋                                              | 121/2163 [00:24<06:47,  5.02it/s, training_loss=0.410]
# Epoch 1:   6%|██▊                                              | 122/2163 [00:24<06:45,  5.03it/s, training_loss=0.410]
# Epoch 1:   6%|██▊                                              | 122/2163 [00:24<06:45,  5.03it/s, training_loss=0.366]
# Epoch 1:   6%|██▊                                              | 123/2163 [00:24<06:45,  5.03it/s, training_loss=0.366]
# Epoch 1:   6%|██▊                                              | 123/2163 [00:25<06:45,  5.03it/s, training_loss=0.447]
# Epoch 1:   6%|██▊                                              | 124/2163 [00:25<06:45,  5.03it/s, training_loss=0.447]
# Epoch 1:   6%|██▊                                              | 124/2163 [00:25<06:45,  5.03it/s, training_loss=0.320]
# Epoch 1:   6%|██▊                                              | 125/2163 [00:25<06:44,  5.03it/s, training_loss=0.320]
# Epoch 1:   6%|██▊                                              | 125/2163 [00:25<06:44,  5.03it/s, training_loss=0.332]
# Epoch 1:   6%|██▊                                              | 126/2163 [00:25<06:43,  5.05it/s, training_loss=0.332]
# Epoch 1:   6%|██▊                                              | 126/2163 [00:25<06:43,  5.05it/s, training_loss=0.679]
# Epoch 1:   6%|██▉                                              | 127/2163 [00:25<06:43,  5.04it/s, training_loss=0.679]
# Epoch 1:   6%|██▉                                              | 127/2163 [00:25<06:43,  5.04it/s, training_loss=0.258]
# Epoch 1:   6%|██▉                                              | 128/2163 [00:25<06:42,  5.06it/s, training_loss=0.258]
# Epoch 1:   6%|██▉                                              | 128/2163 [00:26<06:42,  5.06it/s, training_loss=0.535]
# Epoch 1:   6%|██▉                                              | 129/2163 [00:26<06:42,  5.05it/s, training_loss=0.535]
# Epoch 1:   6%|██▉                                              | 129/2163 [00:26<06:42,  5.05it/s, training_loss=0.393]
# Epoch 1:   6%|██▉                                              | 130/2163 [00:26<06:42,  5.05it/s, training_loss=0.393]
# Epoch 1:   6%|██▉                                              | 130/2163 [00:26<06:42,  5.05it/s, training_loss=0.505]
# Epoch 1:   6%|██▉                                              | 131/2163 [00:26<06:41,  5.06it/s, training_loss=0.505]
# Epoch 1:   6%|██▉                                              | 131/2163 [00:26<06:41,  5.06it/s, training_loss=0.297]
# Epoch 1:   6%|██▉                                              | 132/2163 [00:26<06:41,  5.05it/s, training_loss=0.297]
# Epoch 1:   6%|██▉                                              | 132/2163 [00:26<06:41,  5.05it/s, training_loss=0.330]
# Epoch 1:   6%|███                                              | 133/2163 [00:26<06:41,  5.05it/s, training_loss=0.330]
# Epoch 1:   6%|███                                              | 133/2163 [00:27<06:41,  5.05it/s, training_loss=0.421]
# Epoch 1:   6%|███                                              | 134/2163 [00:27<06:42,  5.05it/s, training_loss=0.421]
# Epoch 1:   6%|███                                              | 134/2163 [00:27<06:42,  5.05it/s, training_loss=0.303]
# Epoch 1:   6%|███                                              | 135/2163 [00:27<06:41,  5.06it/s, training_loss=0.303]
# Epoch 1:   6%|███                                              | 135/2163 [00:27<06:41,  5.06it/s, training_loss=0.309]
# Epoch 1:   6%|███                                              | 136/2163 [00:27<06:41,  5.05it/s, training_loss=0.309]
# Epoch 1:   6%|███                                              | 136/2163 [00:27<06:41,  5.05it/s, training_loss=0.412]
# Epoch 1:   6%|███                                              | 137/2163 [00:27<06:41,  5.05it/s, training_loss=0.412]
# Epoch 1:   6%|███                                              | 137/2163 [00:27<06:41,  5.05it/s, training_loss=0.556]
# Epoch 1:   6%|███▏                                             | 138/2163 [00:27<06:41,  5.04it/s, training_loss=0.556]
# Epoch 1:   6%|███▏                                             | 138/2163 [00:28<06:41,  5.04it/s, training_loss=0.236]
# Epoch 1:   6%|███▏                                             | 139/2163 [00:28<06:40,  5.05it/s, training_loss=0.236]
# Epoch 1:   6%|███▏                                             | 139/2163 [00:28<06:40,  5.05it/s, training_loss=0.448]
# Epoch 1:   6%|███▏                                             | 140/2163 [00:28<06:41,  5.04it/s, training_loss=0.448]
# Epoch 1:   6%|███▏                                             | 140/2163 [00:28<06:41,  5.04it/s, training_loss=0.326]
# Epoch 1:   7%|███▏                                             | 141/2163 [00:28<06:39,  5.06it/s, training_loss=0.326]
# Epoch 1:   7%|███▏                                             | 141/2163 [00:28<06:39,  5.06it/s, training_loss=0.251]
# Epoch 1:   7%|███▏                                             | 142/2163 [00:28<06:39,  5.06it/s, training_loss=0.251]
# Epoch 1:   7%|███▏                                             | 142/2163 [00:28<06:39,  5.06it/s, training_loss=0.493]
# Epoch 1:   7%|███▏                                             | 143/2163 [00:28<06:40,  5.05it/s, training_loss=0.493]
# Epoch 1:   7%|███▏                                             | 143/2163 [00:29<06:40,  5.05it/s, training_loss=0.630]
# Epoch 1:   7%|███▎                                             | 144/2163 [00:29<06:39,  5.05it/s, training_loss=0.630]
# Epoch 1:   7%|███▎                                             | 144/2163 [00:29<06:39,  5.05it/s, training_loss=0.595]
# Epoch 1:   7%|███▎                                             | 145/2163 [00:29<06:38,  5.06it/s, training_loss=0.595]
# Epoch 1:   7%|███▎                                             | 145/2163 [00:29<06:38,  5.06it/s, training_loss=0.296]
# Epoch 1:   7%|███▎                                             | 146/2163 [00:29<06:38,  5.06it/s, training_loss=0.296]
# Epoch 1:   7%|███▎                                             | 146/2163 [00:29<06:38,  5.06it/s, training_loss=0.428]
# Epoch 1:   7%|███▎                                             | 147/2163 [00:29<06:38,  5.06it/s, training_loss=0.428]
# Epoch 1:   7%|███▎                                             | 147/2163 [00:29<06:38,  5.06it/s, training_loss=0.435]
# Epoch 1:   7%|███▎                                             | 148/2163 [00:29<06:38,  5.05it/s, training_loss=0.435]
# Epoch 1:   7%|███▎                                             | 148/2163 [00:30<06:38,  5.05it/s, training_loss=0.646]
# Epoch 1:   7%|███▍                                             | 149/2163 [00:30<06:38,  5.06it/s, training_loss=0.646]
# Epoch 1:   7%|███▍                                             | 149/2163 [00:30<06:38,  5.06it/s, training_loss=0.493]
# Epoch 1:   7%|███▍                                             | 150/2163 [00:30<06:39,  5.04it/s, training_loss=0.493]
# Epoch 1:   7%|███▍                                             | 150/2163 [00:30<06:39,  5.04it/s, training_loss=0.425]
# Epoch 1:   7%|███▍                                             | 151/2163 [00:30<06:38,  5.05it/s, training_loss=0.425]
# Epoch 1:   7%|███▍                                             | 151/2163 [00:30<06:38,  5.05it/s, training_loss=0.245]
# Epoch 1:   7%|███▍                                             | 152/2163 [00:30<06:38,  5.04it/s, training_loss=0.245]
# Epoch 1:   7%|███▍                                             | 152/2163 [00:30<06:38,  5.04it/s, training_loss=0.347]
# Epoch 1:   7%|███▍                                             | 153/2163 [00:30<06:38,  5.04it/s, training_loss=0.347]
# Epoch 1:   7%|███▍                                             | 153/2163 [00:31<06:38,  5.04it/s, training_loss=0.237]
# Epoch 1:   7%|███▍                                             | 154/2163 [00:31<06:38,  5.05it/s, training_loss=0.237]
# Epoch 1:   7%|███▍                                             | 154/2163 [00:31<06:38,  5.05it/s, training_loss=0.246]
# Epoch 1:   7%|███▌                                             | 155/2163 [00:31<06:37,  5.05it/s, training_loss=0.246]
# Epoch 1:   7%|███▌                                             | 155/2163 [00:31<06:37,  5.05it/s, training_loss=0.332]
# Epoch 1:   7%|███▌                                             | 156/2163 [00:31<06:36,  5.06it/s, training_loss=0.332]
# Epoch 1:   7%|███▌                                             | 156/2163 [00:31<06:36,  5.06it/s, training_loss=0.679]
# Epoch 1:   7%|███▌                                             | 157/2163 [00:31<06:37,  5.05it/s, training_loss=0.679]
# Epoch 1:   7%|███▌                                             | 157/2163 [00:31<06:37,  5.05it/s, training_loss=0.419]
# Epoch 1:   7%|███▌                                             | 158/2163 [00:31<06:37,  5.04it/s, training_loss=0.419]
# Epoch 1:   7%|███▌                                             | 158/2163 [00:32<06:37,  5.04it/s, training_loss=0.353]
# Epoch 1:   7%|███▌                                             | 159/2163 [00:32<06:36,  5.05it/s, training_loss=0.353]
# Epoch 1:   7%|███▌                                             | 159/2163 [00:32<06:36,  5.05it/s, training_loss=0.173]
# Epoch 1:   7%|███▌                                             | 160/2163 [00:32<06:37,  5.05it/s, training_loss=0.173]
# Epoch 1:   7%|███▌                                             | 160/2163 [00:32<06:37,  5.05it/s, training_loss=0.147]
# Epoch 1:   7%|███▋                                             | 161/2163 [00:32<06:36,  5.05it/s, training_loss=0.147]
# Epoch 1:   7%|███▋                                             | 161/2163 [00:32<06:36,  5.05it/s, training_loss=0.526]
# Epoch 1:   7%|███▋                                             | 162/2163 [00:32<06:36,  5.05it/s, training_loss=0.526]
# Epoch 1:   7%|███▋                                             | 162/2163 [00:32<06:36,  5.05it/s, training_loss=0.153]
# Epoch 1:   8%|███▋                                             | 163/2163 [00:32<06:35,  5.06it/s, training_loss=0.153]
# Epoch 1:   8%|███▋                                             | 163/2163 [00:33<06:35,  5.06it/s, training_loss=0.391]
# Epoch 1:   8%|███▋                                             | 164/2163 [00:33<06:35,  5.06it/s, training_loss=0.391]
# Epoch 1:   8%|███▋                                             | 164/2163 [00:33<06:35,  5.06it/s, training_loss=0.197]
# Epoch 1:   8%|███▋                                             | 165/2163 [00:33<06:35,  5.05it/s, training_loss=0.197]
# Epoch 1:   8%|███▋                                             | 165/2163 [00:33<06:35,  5.05it/s, training_loss=0.516]
# Epoch 1:   8%|███▊                                             | 166/2163 [00:33<06:35,  5.05it/s, training_loss=0.516]
# Epoch 1:   8%|███▊                                             | 166/2163 [00:33<06:35,  5.05it/s, training_loss=0.408]
# Epoch 1:   8%|███▊                                             | 167/2163 [00:33<06:34,  5.06it/s, training_loss=0.408]
# Epoch 1:   8%|███▊                                             | 167/2163 [00:33<06:34,  5.06it/s, training_loss=0.238]
# Epoch 1:   8%|███▊                                             | 168/2163 [00:33<06:34,  5.06it/s, training_loss=0.238]
# Epoch 1:   8%|███▊                                             | 168/2163 [00:34<06:34,  5.06it/s, training_loss=0.484]
# Epoch 1:   8%|███▊                                             | 169/2163 [00:34<06:35,  5.05it/s, training_loss=0.484]
# Epoch 1:   8%|███▊                                             | 169/2163 [00:34<06:35,  5.05it/s, training_loss=0.051]
# Epoch 1:   8%|███▊                                             | 170/2163 [00:34<06:34,  5.05it/s, training_loss=0.051]
# Epoch 1:   8%|███▊                                             | 170/2163 [00:34<06:34,  5.05it/s, training_loss=0.293]
# Epoch 1:   8%|███▊                                             | 171/2163 [00:34<06:35,  5.04it/s, training_loss=0.293]
# Epoch 1:   8%|███▊                                             | 171/2163 [00:34<06:35,  5.04it/s, training_loss=0.350]
# Epoch 1:   8%|███▉                                             | 172/2163 [00:34<06:34,  5.04it/s, training_loss=0.350]
# Epoch 1:   8%|███▉                                             | 172/2163 [00:34<06:34,  5.04it/s, training_loss=0.236]
# Epoch 1:   8%|███▉                                             | 173/2163 [00:34<06:34,  5.05it/s, training_loss=0.236]
# Epoch 1:   8%|███▉                                             | 173/2163 [00:35<06:34,  5.05it/s, training_loss=0.737]
# Epoch 1:   8%|███▉                                             | 174/2163 [00:35<06:34,  5.05it/s, training_loss=0.737]
# Epoch 1:   8%|███▉                                             | 174/2163 [00:35<06:34,  5.05it/s, training_loss=0.342]
# Epoch 1:   8%|███▉                                             | 175/2163 [00:35<06:33,  5.05it/s, training_loss=0.342]
# Epoch 1:   8%|███▉                                             | 175/2163 [00:35<06:33,  5.05it/s, training_loss=0.156]
# Epoch 1:   8%|███▉                                             | 176/2163 [00:35<06:33,  5.05it/s, training_loss=0.156]
# Epoch 1:   8%|███▉                                             | 176/2163 [00:35<06:33,  5.05it/s, training_loss=0.246]
# Epoch 1:   8%|████                                             | 177/2163 [00:35<06:34,  5.04it/s, training_loss=0.246]
# Epoch 1:   8%|████                                             | 177/2163 [00:35<06:34,  5.04it/s, training_loss=0.210]
# Epoch 1:   8%|████                                             | 178/2163 [00:35<06:33,  5.04it/s, training_loss=0.210]
# Epoch 1:   8%|████                                             | 178/2163 [00:36<06:33,  5.04it/s, training_loss=0.057]
# Epoch 1:   8%|████                                             | 179/2163 [00:36<06:33,  5.04it/s, training_loss=0.057]
# Epoch 1:   8%|████                                             | 179/2163 [00:36<06:33,  5.04it/s, training_loss=0.519]
# Epoch 1:   8%|████                                             | 180/2163 [00:36<06:34,  5.03it/s, training_loss=0.519]
# Epoch 1:   8%|████                                             | 180/2163 [00:36<06:34,  5.03it/s, training_loss=0.605]
# Epoch 1:   8%|████                                             | 181/2163 [00:36<06:33,  5.03it/s, training_loss=0.605]
# Epoch 1:   8%|████                                             | 181/2163 [00:36<06:33,  5.03it/s, training_loss=0.353]
# Epoch 1:   8%|████                                             | 182/2163 [00:36<06:33,  5.04it/s, training_loss=0.353]
# Epoch 1:   8%|████                                             | 182/2163 [00:36<06:33,  5.04it/s, training_loss=0.050]
# Epoch 1:   8%|████▏                                            | 183/2163 [00:36<06:32,  5.05it/s, training_loss=0.050]
# Epoch 1:   8%|████▏                                            | 183/2163 [00:37<06:32,  5.05it/s, training_loss=0.268]
# Epoch 1:   9%|████▏                                            | 184/2163 [00:37<06:32,  5.05it/s, training_loss=0.268]
# Epoch 1:   9%|████▏                                            | 184/2163 [00:37<06:32,  5.05it/s, training_loss=0.610]
# Epoch 1:   9%|████▏                                            | 185/2163 [00:37<06:31,  5.06it/s, training_loss=0.610]
# Epoch 1:   9%|████▏                                            | 185/2163 [00:37<06:31,  5.06it/s, training_loss=0.453]
# Epoch 1:   9%|████▏                                            | 186/2163 [00:37<06:31,  5.05it/s, training_loss=0.453]
# Epoch 1:   9%|████▏                                            | 186/2163 [00:37<06:31,  5.05it/s, training_loss=0.378]
# Epoch 1:   9%|████▏                                            | 187/2163 [00:37<06:31,  5.04it/s, training_loss=0.378]
# Epoch 1:   9%|████▏                                            | 187/2163 [00:37<06:31,  5.04it/s, training_loss=0.256]
# Epoch 1:   9%|████▎                                            | 188/2163 [00:37<06:31,  5.04it/s, training_loss=0.256]
# Epoch 1:   9%|████▎                                            | 188/2163 [00:38<06:31,  5.04it/s, training_loss=0.238]
# Epoch 1:   9%|████▎                                            | 189/2163 [00:38<06:30,  5.05it/s, training_loss=0.238]
# Epoch 1:   9%|████▎                                            | 189/2163 [00:38<06:30,  5.05it/s, training_loss=0.337]
# Epoch 1:   9%|████▎                                            | 190/2163 [00:38<06:30,  5.05it/s, training_loss=0.337]
# Epoch 1:   9%|████▎                                            | 190/2163 [00:38<06:30,  5.05it/s, training_loss=0.350]
# Epoch 1:   9%|████▎                                            | 191/2163 [00:38<06:31,  5.04it/s, training_loss=0.350]
# Epoch 1:   9%|████▎                                            | 191/2163 [00:38<06:31,  5.04it/s, training_loss=0.512]
# Epoch 1:   9%|████▎                                            | 192/2163 [00:38<06:31,  5.03it/s, training_loss=0.512]
# Epoch 1:   9%|████▎                                            | 192/2163 [00:38<06:31,  5.03it/s, training_loss=0.206]
# Epoch 1:   9%|████▎                                            | 193/2163 [00:38<06:31,  5.03it/s, training_loss=0.206]
# Epoch 1:   9%|████▎                                            | 193/2163 [00:39<06:31,  5.03it/s, training_loss=0.332]
# Epoch 1:   9%|████▍                                            | 194/2163 [00:39<06:30,  5.04it/s, training_loss=0.332]
# Epoch 1:   9%|████▍                                            | 194/2163 [00:39<06:30,  5.04it/s, training_loss=0.376]
# Epoch 1:   9%|████▍                                            | 195/2163 [00:39<06:30,  5.04it/s, training_loss=0.376]
# Epoch 1:   9%|████▍                                            | 195/2163 [00:39<06:30,  5.04it/s, training_loss=0.045]
# Epoch 1:   9%|████▍                                            | 196/2163 [00:39<06:29,  5.06it/s, training_loss=0.045]
# Epoch 1:   9%|████▍                                            | 196/2163 [00:39<06:29,  5.06it/s, training_loss=0.176]
# Epoch 1:   9%|████▍                                            | 197/2163 [00:39<06:29,  5.05it/s, training_loss=0.176]
# Epoch 1:   9%|████▍                                            | 197/2163 [00:39<06:29,  5.05it/s, training_loss=0.260]
# Epoch 1:   9%|████▍                                            | 198/2163 [00:39<06:29,  5.05it/s, training_loss=0.260]
# Epoch 1:   9%|████▍                                            | 198/2163 [00:39<06:29,  5.05it/s, training_loss=0.384]
# Epoch 1:   9%|████▌                                            | 199/2163 [00:39<06:29,  5.04it/s, training_loss=0.384]
# ...
# Epoch 5:  97%|██████████████████████████████████████████████▌ | 2098/2163 [06:52<00:12,  5.11it/s, training_loss=0.188]
# Epoch 5:  97%|██████████████████████████████████████████████▌ | 2099/2163 [06:52<00:12,  5.08it/s, training_loss=0.188]
# Epoch 5:  97%|██████████████████████████████████████████████▌ | 2099/2163 [06:52<00:12,  5.08it/s, training_loss=0.000]
# Epoch 5:  97%|██████████████████████████████████████████████▌ | 2100/2163 [06:52<00:12,  5.12it/s, training_loss=0.000]
# Epoch 5:  97%|██████████████████████████████████████████████▌ | 2100/2163 [06:52<00:12,  5.12it/s, training_loss=0.000]
# Epoch 5:  97%|██████████████████████████████████████████████▌ | 2101/2163 [06:52<00:12,  5.14it/s, training_loss=0.000]
# Epoch 5:  97%|██████████████████████████████████████████████▌ | 2101/2163 [06:52<00:12,  5.14it/s, training_loss=0.225]
# Epoch 5:  97%|██████████████████████████████████████████████▋ | 2102/2163 [06:52<00:11,  5.11it/s, training_loss=0.225]
# Epoch 5:  97%|██████████████████████████████████████████████▋ | 2102/2163 [06:53<00:11,  5.11it/s, training_loss=0.696]
# Epoch 5:  97%|██████████████████████████████████████████████▋ | 2103/2163 [06:53<00:11,  5.08it/s, training_loss=0.696]
# Epoch 5:  97%|██████████████████████████████████████████████▋ | 2103/2163 [06:53<00:11,  5.08it/s, training_loss=0.086]
# Epoch 5:  97%|██████████████████████████████████████████████▋ | 2104/2163 [06:53<00:11,  5.07it/s, training_loss=0.086]
# Epoch 5:  97%|██████████████████████████████████████████████▋ | 2104/2163 [06:53<00:11,  5.07it/s, training_loss=0.000]
# Epoch 5:  97%|██████████████████████████████████████████████▋ | 2105/2163 [06:53<00:11,  5.11it/s, training_loss=0.000]
# Epoch 5:  97%|██████████████████████████████████████████████▋ | 2105/2163 [06:53<00:11,  5.11it/s, training_loss=0.003]
# Epoch 5:  97%|██████████████████████████████████████████████▋ | 2106/2163 [06:53<00:11,  5.09it/s, training_loss=0.003]
# Epoch 5:  97%|██████████████████████████████████████████████▋ | 2106/2163 [06:53<00:11,  5.09it/s, training_loss=0.000]
# Epoch 5:  97%|██████████████████████████████████████████████▊ | 2107/2163 [06:53<00:10,  5.11it/s, training_loss=0.000]
# Epoch 5:  97%|██████████████████████████████████████████████▊ | 2107/2163 [06:54<00:10,  5.11it/s, training_loss=0.000]
# Epoch 5:  97%|██████████████████████████████████████████████▊ | 2108/2163 [06:54<00:10,  5.15it/s, training_loss=0.000]
# Epoch 5:  97%|██████████████████████████████████████████████▊ | 2108/2163 [06:54<00:10,  5.15it/s, training_loss=0.000]
# Epoch 5:  98%|██████████████████████████████████████████████▊ | 2109/2163 [06:54<00:10,  5.17it/s, training_loss=0.000]
# Epoch 5:  98%|██████████████████████████████████████████████▊ | 2109/2163 [06:54<00:10,  5.17it/s, training_loss=0.198]
# Epoch 5:  98%|██████████████████████████████████████████████▊ | 2110/2163 [06:54<00:10,  5.12it/s, training_loss=0.198]
# Epoch 5:  98%|██████████████████████████████████████████████▊ | 2110/2163 [06:54<00:10,  5.12it/s, training_loss=0.105]
# Epoch 5:  98%|██████████████████████████████████████████████▊ | 2111/2163 [06:54<00:10,  5.09it/s, training_loss=0.105]
# Epoch 5:  98%|██████████████████████████████████████████████▊ | 2111/2163 [06:54<00:10,  5.09it/s, training_loss=0.114]
# Epoch 5:  98%|██████████████████████████████████████████████▊ | 2112/2163 [06:54<00:10,  5.06it/s, training_loss=0.114]
# Epoch 5:  98%|██████████████████████████████████████████████▊ | 2112/2163 [06:55<00:10,  5.06it/s, training_loss=0.214]
# Epoch 5:  98%|██████████████████████████████████████████████▉ | 2113/2163 [06:55<00:09,  5.06it/s, training_loss=0.214]
# Epoch 5:  98%|██████████████████████████████████████████████▉ | 2113/2163 [06:55<00:09,  5.06it/s, training_loss=0.000]
# Epoch 5:  98%|██████████████████████████████████████████████▉ | 2114/2163 [06:55<00:09,  5.10it/s, training_loss=0.000]
# Epoch 5:  98%|██████████████████████████████████████████████▉ | 2114/2163 [06:55<00:09,  5.10it/s, training_loss=0.002]
# Epoch 5:  98%|██████████████████████████████████████████████▉ | 2115/2163 [06:55<00:09,  5.12it/s, training_loss=0.002]
# Epoch 5:  98%|██████████████████████████████████████████████▉ | 2115/2163 [06:55<00:09,  5.12it/s, training_loss=0.001]
# Epoch 5:  98%|██████████████████████████████████████████████▉ | 2116/2163 [06:55<00:09,  5.14it/s, training_loss=0.001]
# Epoch 5:  98%|██████████████████████████████████████████████▉ | 2116/2163 [06:55<00:09,  5.14it/s, training_loss=0.278]
# Epoch 5:  98%|██████████████████████████████████████████████▉ | 2117/2163 [06:55<00:09,  5.11it/s, training_loss=0.278]
# Epoch 5:  98%|██████████████████████████████████████████████▉ | 2117/2163 [06:55<00:09,  5.11it/s, training_loss=0.125]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2118/2163 [06:55<00:08,  5.08it/s, training_loss=0.125]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2118/2163 [06:56<00:08,  5.08it/s, training_loss=0.002]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2119/2163 [06:56<00:08,  5.07it/s, training_loss=0.002]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2119/2163 [06:56<00:08,  5.07it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2120/2163 [06:56<00:08,  5.10it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2120/2163 [06:56<00:08,  5.10it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2121/2163 [06:56<00:08,  5.13it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2121/2163 [06:56<00:08,  5.13it/s, training_loss=0.003]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2122/2163 [06:56<00:08,  5.10it/s, training_loss=0.003]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2122/2163 [06:56<00:08,  5.10it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2123/2163 [06:56<00:07,  5.12it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████ | 2123/2163 [06:57<00:07,  5.12it/s, training_loss=0.004]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2124/2163 [06:57<00:07,  5.10it/s, training_loss=0.004]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2124/2163 [06:57<00:07,  5.10it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2125/2163 [06:57<00:07,  5.12it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2125/2163 [06:57<00:07,  5.12it/s, training_loss=0.001]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2126/2163 [06:57<00:07,  5.15it/s, training_loss=0.001]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2126/2163 [06:57<00:07,  5.15it/s, training_loss=0.119]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2127/2163 [06:57<00:07,  5.11it/s, training_loss=0.119]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2127/2163 [06:57<00:07,  5.11it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2128/2163 [06:57<00:06,  5.14it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2128/2163 [06:58<00:06,  5.14it/s, training_loss=0.001]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2129/2163 [06:58<00:06,  5.15it/s, training_loss=0.001]
# Epoch 5:  98%|███████████████████████████████████████████████▏| 2129/2163 [06:58<00:06,  5.15it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████▎| 2130/2163 [06:58<00:06,  5.16it/s, training_loss=0.000]
# Epoch 5:  98%|███████████████████████████████████████████████▎| 2130/2163 [06:58<00:06,  5.16it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▎| 2131/2163 [06:58<00:06,  5.18it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▎| 2131/2163 [06:58<00:06,  5.18it/s, training_loss=0.002]
# Epoch 5:  99%|███████████████████████████████████████████████▎| 2132/2163 [06:58<00:06,  5.11it/s, training_loss=0.002]
# Epoch 5:  99%|███████████████████████████████████████████████▎| 2132/2163 [06:58<00:06,  5.11it/s, training_loss=0.000]
# Epoch 5:  99%|███████████████████████████████████████████████▎| 2133/2163 [06:58<00:05,  5.14it/s, training_loss=0.000]
# Epoch 5:  99%|███████████████████████████████████████████████▎| 2133/2163 [06:59<00:05,  5.14it/s, training_loss=0.451]
# Epoch 5:  99%|███████████████████████████████████████████████▎| 2134/2163 [06:59<00:05,  5.11it/s, training_loss=0.451]
# Epoch 5:  99%|███████████████████████████████████████████████▎| 2134/2163 [06:59<00:05,  5.11it/s, training_loss=0.101]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2135/2163 [06:59<00:05,  5.09it/s, training_loss=0.101]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2135/2163 [06:59<00:05,  5.09it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2136/2163 [06:59<00:05,  5.12it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2136/2163 [06:59<00:05,  5.12it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2137/2163 [06:59<00:05,  5.14it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2137/2163 [06:59<00:05,  5.14it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2138/2163 [06:59<00:04,  5.16it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2138/2163 [07:00<00:04,  5.16it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2139/2163 [07:00<00:04,  5.17it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2139/2163 [07:00<00:04,  5.17it/s, training_loss=0.672]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2140/2163 [07:00<00:04,  5.12it/s, training_loss=0.672]
# Epoch 5:  99%|███████████████████████████████████████████████▍| 2140/2163 [07:00<00:04,  5.12it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2141/2163 [07:00<00:04,  5.13it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2141/2163 [07:00<00:04,  5.13it/s, training_loss=0.000]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2142/2163 [07:00<00:04,  5.15it/s, training_loss=0.000]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2142/2163 [07:00<00:04,  5.15it/s, training_loss=0.000]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2143/2163 [07:00<00:03,  5.17it/s, training_loss=0.000]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2143/2163 [07:01<00:03,  5.17it/s, training_loss=0.385]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2144/2163 [07:01<00:03,  5.13it/s, training_loss=0.385]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2144/2163 [07:01<00:03,  5.13it/s, training_loss=0.010]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2145/2163 [07:01<00:03,  5.10it/s, training_loss=0.010]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2145/2163 [07:01<00:03,  5.10it/s, training_loss=0.003]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2146/2163 [07:01<00:03,  5.08it/s, training_loss=0.003]
# Epoch 5:  99%|███████████████████████████████████████████████▌| 2146/2163 [07:01<00:03,  5.08it/s, training_loss=0.003]
# Epoch 5:  99%|███████████████████████████████████████████████▋| 2147/2163 [07:01<00:03,  5.07it/s, training_loss=0.003]
# Epoch 5:  99%|███████████████████████████████████████████████▋| 2147/2163 [07:01<00:03,  5.07it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▋| 2148/2163 [07:01<00:02,  5.11it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▋| 2148/2163 [07:02<00:02,  5.11it/s, training_loss=0.026]
# Epoch 5:  99%|███████████████████████████████████████████████▋| 2149/2163 [07:02<00:02,  5.09it/s, training_loss=0.026]
# Epoch 5:  99%|███████████████████████████████████████████████▋| 2149/2163 [07:02<00:02,  5.09it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▋| 2150/2163 [07:02<00:02,  5.12it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▋| 2150/2163 [07:02<00:02,  5.12it/s, training_loss=0.331]
# Epoch 5:  99%|███████████████████████████████████████████████▋| 2151/2163 [07:02<00:02,  5.09it/s, training_loss=0.331]
# Epoch 5:  99%|███████████████████████████████████████████████▋| 2151/2163 [07:02<00:02,  5.09it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▊| 2152/2163 [07:02<00:02,  5.12it/s, training_loss=0.001]
# Epoch 5:  99%|███████████████████████████████████████████████▊| 2152/2163 [07:02<00:02,  5.12it/s, training_loss=0.001]
# Epoch 5: 100%|███████████████████████████████████████████████▊| 2153/2163 [07:02<00:01,  5.14it/s, training_loss=0.001]
# Epoch 5: 100%|███████████████████████████████████████████████▊| 2153/2163 [07:03<00:01,  5.14it/s, training_loss=0.012]
# Epoch 5: 100%|███████████████████████████████████████████████▊| 2154/2163 [07:03<00:01,  5.10it/s, training_loss=0.012]
# Epoch 5: 100%|███████████████████████████████████████████████▊| 2154/2163 [07:03<00:01,  5.10it/s, training_loss=0.311]
# Epoch 5: 100%|███████████████████████████████████████████████▊| 2155/2163 [07:03<00:01,  5.08it/s, training_loss=0.311]
# Epoch 5: 100%|███████████████████████████████████████████████▊| 2155/2163 [07:03<00:01,  5.08it/s, training_loss=0.115]
# Epoch 5: 100%|███████████████████████████████████████████████▊| 2156/2163 [07:03<00:01,  5.06it/s, training_loss=0.115]
# Epoch 5: 100%|███████████████████████████████████████████████▊| 2156/2163 [07:03<00:01,  5.06it/s, training_loss=0.003]
# Epoch 5: 100%|███████████████████████████████████████████████▊| 2157/2163 [07:03<00:01,  5.05it/s, training_loss=0.003]
# Epoch 5: 100%|███████████████████████████████████████████████▊| 2157/2163 [07:03<00:01,  5.05it/s, training_loss=0.000]
# Epoch 5: 100%|███████████████████████████████████████████████▉| 2158/2163 [07:03<00:00,  5.09it/s, training_loss=0.000]
# Epoch 5: 100%|███████████████████████████████████████████████▉| 2158/2163 [07:03<00:00,  5.09it/s, training_loss=0.025]
# Epoch 5: 100%|███████████████████████████████████████████████▉| 2159/2163 [07:03<00:00,  5.07it/s, training_loss=0.025]
# Epoch 5: 100%|███████████████████████████████████████████████▉| 2159/2163 [07:04<00:00,  5.07it/s, training_loss=0.001]
# Epoch 5: 100%|███████████████████████████████████████████████▉| 2160/2163 [07:04<00:00,  5.11it/s, training_loss=0.001]
# Epoch 5: 100%|███████████████████████████████████████████████▉| 2160/2163 [07:04<00:00,  5.11it/s, training_loss=0.000]
# Epoch 5: 100%|███████████████████████████████████████████████▉| 2161/2163 [07:04<00:00,  5.13it/s, training_loss=0.000]
# Epoch 5: 100%|███████████████████████████████████████████████▉| 2161/2163 [07:04<00:00,  5.13it/s, training_loss=0.255]
# Epoch 5: 100%|███████████████████████████████████████████████▉| 2162/2163 [07:04<00:00,  5.09it/s, training_loss=0.255]
# Epoch 5: 100%|███████████████████████████████████████████████▉| 2162/2163 [07:04<00:00,  5.09it/s, training_loss=0.010]
# Epoch 5: 100%|████████████████████████████████████████████████| 2163/2163 [07:04<00:00,  5.68it/s, training_loss=0.010]
#  80%|██████████████████████████████████████████████████████████████████▍                | 4/5 [36:42<07:23, 443.67s/it]
# Epoch 5
# Training loss: 0.3605781163620422
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [36:58<00:00, 443.71s/it]
# Validation loss: 0.7166140007874678
# F1 Score (Weighted): 0.8131687857607165

# %% [markdown]
# # Loading and Evaluating the Model

# %%
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-multilingual-cased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)

model.to(device)
# Out:
# Some weights of the model checkpoint at distilbert-base-multilingual-cased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-multilingual-cased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(119547, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=4, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
model.load_state_dict(torch.load('finetuned_BERT_epoch_1.pt', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
_, predictions, true_vals = evaluate(dataloader_validation)

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# label_dict_inverse: {0: '경영, 비즈니스', 1: '개발', 2: '디자인', 3: '마케팅, 광고'}
# Class: 경영, 비즈니스
# Accuracy: 197/270
#
# Class: 개발
# Accuracy: 487/513
#
# Class: 디자인
# Accuracy: 94/158
#
# Class: 마케팅, 광고
# Accuracy: 129/204

# %% [markdown]
# # test

# %%
test_text =['''
머신러닝 응용 엔지니어 
• 머신러닝 모델 을 이용한 서비스, REST API 개발 및 제공 (Python)
• 머신러닝 인프라 설계 및 운영
• 원티드의 기업문화와 잘 맞는 분 (https://www.wantedlab.team/our-story)
• REST API에 대한 설계 및 개발 경험과 이해
• 클라우드(AWS, GCP, Azure등등)를 이용한 서비스 구축, 운영경험
• Tensorflow 또는 Pytorch 모델 서빙 경험
• MySQL 호환 DB 사용경험
• 머신러닝에 대한 이해
• 추천시스템 구축 경험
• 데이터 파이프라인 구축 경험
• 웹 대시보드 개발 경험
• 서버 외 다른 플랫폼 개발에 대한 오픈 마인드
''']

# %%
tokenizer = DistilBertTokenizer.from_pretrained(MODEL_NAME, do_lower_case=True )

# model.load_state_dict(torch.load('finetuned_BERT_epoch_1.pt', map_location=torch.device('cpu')))
model.load_state_dict(torch.load('finetuned_BERT_epoch_1.pt', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# device(type='cuda')

# %%
encoded_inputs = tokenizer.batch_encode_plus(
    test_text,
    max_length=250,
    padding=True,
    truncation=True,
    return_token_type_ids=False,
)

# %%
input_ids = torch.tensor(encoded_inputs["input_ids"])
attention_masks = torch.tensor(encoded_inputs["attention_mask"])

# %%
def evaluate1(dataloader_val):
    model.eval()
    predictions, probs = [], []
    
    for batch in dataloader_val:
        batch = tuple(b.to("cuda") for b in batch)
#         batch = tuple(b for b in batch)
        inputs = {"input_ids": batch[0], "attention_mask": batch[1]}

        with torch.no_grad():
            outputs = model(**inputs)

        logits = outputs[0]
        predictions.append(logits.detach().cpu().numpy())
#         predictions.append(logits.detach().numpy())
        softmax = torch.nn.Softmax(dim=1)
        probs.append(softmax(logits).detach().cpu().numpy())
#         probs.append(softmax(logits).detach().numpy())

    predictions = np.concatenate(predictions, axis=0)
    probs = np.concatenate(probs, axis=0)
    return predictions, probs

# %%
tensor_ds = TensorDataset(input_ids, attention_masks)
data_loader = DataLoader(
    tensor_ds, sampler=SequentialSampler(tensor_ds), batch_size=1
)
classes, probs = evaluate1(data_loader)

# %%
class_mapping = {
        0: '경영, 비즈니스',
        1: "개발",
        2: "디자인",
        3: "마케팅, 광고",
    }

# {'경영, 비즈니스': 0, '개발': 1, '디자인': 2, '마케팅, 광고': 3}

# %%
results = []


for predicted_class, prob in zip(classes, probs):
#     print(np.argmax(predicted_class))
#     print(float(np.max(prob)))
    predicted_class = class_mapping[int(np.argmax(predicted_class))]
    confidence = float(np.max(prob))
    results.append(
        {"class": predicted_class, "confidence": confidence,}
    )
#     client.report_insights({"model_confidence": confidence})

print(results)
# Out:
# [{'class': '개발', 'confidence': 0.9987719655036926}]
